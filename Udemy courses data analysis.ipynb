# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the udemy data set in pandas Datafraame

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\7. Udemy Courses.csv")
df.head(10)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5    1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6    1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7     768028  * An Integrated Approach to the Fundamentals o...     True
# 8     206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9     738910  [Value Investing] Where White People Keep Thei...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# ...

# %% [markdown]
# # Basic info

# %%
df.count()
df.corr()
df.isnull().sum()
df.columns
sns.heatmap(df.isnull())
df.describe()
df.shape
df.size
df.notnull().sum()
df.notnull().sum().sum() # it tells total values that is not null
df.notnull().sum()
#sns.heatmap(df.notnull())
df.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %% [markdown]
# # Q. 1) What are all different subjects for which Udemy is offering courses ?

# %%
df.head()
df
df1 = df['subject'].unique()
print("All Different subjects are : ",df1)
#-------------or------------
df.subject.unique()
# Out:
# All Different subjects are :  ['Musical Instruments' 'Business Finance' 'Graphic Design'
#  'Web Development']
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # Q. 2) Which subject has the maximum number of courses.

# %%
df.head(2)
df2 = df['subject'].value_counts()
print(df2)
print()
max_course = df2.idxmax()
print("maximum number of courses : ",max_course)
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64
#
# maximum number of courses :  Web Development

# %%
df.head(2)
df2 = df.subject.value_counts().sort_values(ascending=False).head(1)
print("max number of courses : ",df2)
# Out:
# max number of courses :  Web Development    1200
# Name: subject, dtype: int64

# %% [markdown]
# # Q. 3) Show all the courses which are Free of Cost.

# %%
df[df.is_paid==False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %% [markdown]
# # Q. 4) Show all the courses which are Paid.

# %%
df[df.is_paid==True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# # Q. 5) Which are Top Selling Courses ?

# %%
df4 = df['num_subscribers'].sort_values(ascending=False)
print(df4.head())
# Out:
# 2230    268923
# 776     161029
# 3385    121584
# 640     120291
# 3316    114512
# Name: num_subscribers, dtype: int64

# %%
df4 = df.sort_values('num_subscribers',ascending=False)
print(df4.head(1))
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2230           268923         8629            45  All Levels       10.5 hours
#
#        published_timestamp          subject
# 2230  2013-02-14T07:03:41Z  Web Development

# %% [markdown]
# # Q. 6) Which are Least Selling Courses ?

# %%
df6 = df['num_subscribers'].sort_values(ascending=True)
print(df6.head(3))
# Out:
# 649     0
# 3259    0
# 3261    0
# Name: num_subscribers, dtype: int64

# %%
df6 = df.sort_values('num_subscribers',ascending=True)
print(df6.head())
# Out:
#       course_id                                  course_title  is_paid price  \
# 649     1233314                 Building a Balanced Scorecard     True    50
# 3259    1232282     The Cash Flow Statement - An Introduction     True    50
# 3261    1275872               The Complete Adobe Spark Course     True   150
# 910      726314  Create Beautiful Image Maps for Your Website     True    20
# 3328     715476   The Cuckoo Strategy to get European Funding     True   160
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 649                 0            0            11  Intermediate Level
# 3259                0            0            10      Beginner Level
# 3261                0            0            29          All Levels
# 910                 0            0             8  Intermediate Level
# 3328                0            0             6          All Levels
#
#      content_duration   published_timestamp           subject
# ...

# %% [markdown]
# # Q. 7) Show all courses of Graphic Design where the price is below 100 ?

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\7. Udemy Courses.csv")
df.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
df[(df.subject=='Graphic Design') & (df.price<'100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df[(df.subject=='Graphic Design') & (df.price=='100')]
# Out:
#       course_id                                       course_title  is_paid  \
# 47      1269190          7 Secrets To Designing In Black and White     True
# 169      983444       Adobe Illustrator Vectors For Hand Letterers     True
# 184      638040  Adobe Photoshop Essentials: Master Adobe Photo...     True
# 520      978462              Blender Modelling Series - Volume Two     True
# 699      757900                          Canva : Book Cover Design     True
# 1029    1160004                 Design a logo for FREE in Inkscape     True
# 1071    1161864  Diseño impreso - Preimpresión para offset en I...     True
# 1444     490392                Getting Started with Illustrator CC     True
# 1568     727510             How To Become An Etsy Wholesale Seller     True
# 1616     996868          How to Design a Logo in Adobe Illustrator     True
# 1697     654038              How To Sell Your Art Online With ETSY     True
# ...

# %% [markdown]
# # Q. 8) List out all the courses that are related to 'Python'.

# %%
df[(df.course_title.str.contains('Python'))]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %% [markdown]
# # Q. 9) What are courses that were published in the year 2015 ?

# %%
df.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
df[(df.published_timestamp.str.contains('2015'))]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
df.dtypes
df['published_timestamp']=pd.to_datetime(df.published_timestamp)  # convert object into datetime
df.dtypes
df['year']=df["published_timestamp"].dt.year
df[df.year==2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# # Q. 10) What is the Max. Number of Subscribers for Each Level of courses ?

# %%
df.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %% [markdown]
# # --------------COMPLETED-----------------
